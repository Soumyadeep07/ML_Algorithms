# %%
import nltk

file1=open(r"E:\5thSem\Algo Project\doc1.txt","r")
text1=file1.readline()
#print(text1)
data1=file1.read()
character1=len(data1)

print("\n")

file2=open(r"E:\5thSem\Algo Project\doc2.txt","r")
text2=file2.readline()
#print(text2+"\n")

str1=''.join(text1)
str2=''.join(text2)
#print(str1+"\n")
#print(str2+"\n")

sent_text1=str1.split('.')
sent_text2=str2.split('.')
print(sent_text1)
print("\n")
print(sent_text2)
print("\n")

final=[]
for i in sent_text1:
	for j in sent_text2:
		if i==j:
			final.append(i)
print(final)
# Out:
# ['Long ago, when there was no written history, these islands were the home of millions of happy birds; the resort of a hundred times more millions of fishes, sea lions, and other creatures', ' Here lived innumerable creatures predestined from the creation of the world to lay up a store of wealth for the British farmer, and a store of quite another sort for an immaculate Republican government', '']
#
#
# ['Long ago, when there was no written histaory, these islands were the home of millions of happy birds; the resort of a hundred times more millions of fishes, sea lions, and other creatures', ' Here lived innumerable creatures predestined from the creation of the world to lay up a store of wealth for the British farmer, and a store of quite another sort for an immaculate Republican government', '']
#
#
# ...

# %%
import nltk

file1=open(r"E:\5thSem\Algo Project\doc1.txt","r")
text1=file1.readline()
#print(text1)

print("\n")

file2=open(r"E:\5thSem\Algo Project\doc2.txt","r")
text2=file2.readline()
#print(text2+"\n")

str1=''.join(text1)
str2=''.join(text2)
#print(str1+"\n")
#print(str2+"\n")

sent_text1=str1.split('.')
sent_text2=str2.split('.')
print(sent_text1)
print("\n")
print(sent_text2)
print("\n")

character1=len(sent_text1)

fc=0
final=[]
for i in sent_text1:
	for j in sent_text2:
		if i==j:
			final.append(i)
            fc=fc+1
print(final)

fd=0
for _ in sent_text1:
    fd=fd+1

print(fc,fd)

'''character2=len(final)
print("\n\nTotal characters in file 1: ",character1)
print("Total no of characters matched :",character2)
print("Percentage of character matched : ",(character2*100)/character1," % ")
print("\n")'''
# Out:
#   File "<tokenize>", line 33
#     fc=fc+1
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import nltk

file1=open(r"E:\5thSem\Algo Project\doc1.txt","r")
data1=file1.read()
#print(len(data1))
print(data1)

file2=open(r"E:\5thSem\Algo Project\doc2.txt","r")
data2=file2.read()
#print(len(data2)) 
print(data2)

final=[]
for i in data1:
	for j in data2:
		if i==j:
			final.append(i)
print(final)
# Out:
# Long ago, when there was no written history, these islands were the home of millions of happy birds; the resort of a hundred times more millions of fishes, sea lions, and other creatures. Here lived innumerable creatures predestined from the creation of the world to lay up a store of wealth for the British farmer, and a store of quite another sort for an immaculate Republican government.
# Long ago, when there was no written histaory, these islands were the home of millions of happy birds; the resort of a hundred times more millions of fishes, sea lions, and other creatures. Here lived innumerable creatures predestined from the creation of the world to lay up a store of wealth for the British farmer, and a store of quite another sort for an immaculate Republican government.
# ...
